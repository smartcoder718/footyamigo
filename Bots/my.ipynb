# %%
maps = """1	8
2	9
3	7
4	5
5	6
6	4
7	2
8	3
9	1
10	16
11	15
12	18
13	17
14	14
15	13
16	22
17	21
18	24
19	23
20	20
21	19
22	26
23	25
24	10
25	11
26	12
27	26
28	8
29	9
30	7
31	23
32	22
33	21
34	24
35	25
36	5
37	6
38	4
39	2
40	3
41	1
42	20
43	19
44	18
45	17
46	10
47	11
48	12
49	13
50	14
51	15
52	16
68	8
54	7
55	4
56	6
57	999
58	999
59	999
60	1
61	2
62	3
63	5
53	42
64	43
65	44
66	45
67	46
69	32
70	34
71	31
72	30
73	36
74	37
75	35
76	39
77	40
78	38
79	41
80	8
81	7
82	6
83	47
84	48
85	5
86	50
87	11
88	10
89	9
90	12
91	13
92	49
93	15
94	16
95	14
96	18
97	19
98	17
99	20
100	21
101	3
102	4
103	22
104	2
105	51
106	24
107	25
108	23
109	27
110	28
111	26
112	29
113	1
114	3
115	2
116	4
117	5
118	1
119	3
120	4
121	56
122	9
123	11
124	12
125	13
126	14
127	10
128	7
129	8
130	5
131	6
132	50
133	51
134	52
135	47
136	48
137	49
138	1
139	2
140	53
141	54
142	55
143	999
144	999
145	15
146	35
147	999
148	999
149	999
150	999
151	999
152	999
153	999
154	999
155	999
156	999
157	999
158	999
159	999
160	999
161	999
162	999
163	999
164	999
165	999
166	999
167	999
168	999
169	999
170	999
171	999
172	999
173	999
174	999
175	16
176	36
177	999
178	999
179	999
180	999
181	999
182	999
183	999
184	999
185	999
186	999
187	999
188	999
189	999
190	999
191	999
192	999
193	999
194	999
195	999
196	999
197	999
198	999
199	999
200	999
201	17
202	37
203	999
204	999
205	999
206	999
207	18
208	38
209	999
210	999
211	999
212	999
213	19
214	39
215	999
216	999
217	999
218	999
219	20
220	40
221	999
222	999
223	999
224	999
225	21
226	999
227	999
228	999
229	999
230	22
231	999
232	999
233	999
234	999
235	999
236	23
237	999
238	999
239	999
240	999
241	999
242	999
243	999
244	999
245	999
246	999
247	999
248	24
249	41
250	999
251	999
252	999
253	999
254	999
255	999
256	999
257	999
258	999
259	999
260	999
261	999
262	999
263	999
264	999
265	999
266	999
267	999
268	999
269	999
270	999
271	999
272	999
273	999
274	999
275	999
276	999
277	999
278	25
279	42
280	999
281	999
282	999
283	999
284	999
285	999
286	999
287	999
288	999
289	999
290	999
291	999
292	999
293	999
294	999
295	999
296	999
297	999
298	999
299	999
300	999
301	999
302	999
303	999
304	26
305	43
306	999
307	999
308	999
309	999
310	27
311	44
312	999
313	999
314	999
315	999
316	28
317	45
318	999
319	999
320	999
321	999
322	29
323	46
324	999
325	999
326	999
327	999
328	30
329	999
330	999
331	999
332	999
333	31
334	999
335	999
336	999
337	999
338	999
339	32
340	999
341	999
342	999
343	999
344	999
345	999
346	999
347	999
348	33
349	34
350	9
351	11
352	12
353	10
354	2
355	4
356	3
357	5
358	7
359	8
360	6
361	1
362	13
363	14
364	14
365	15
366	7
367	5
368	6
369	4
370	14
371	9
372	13
373	8
374	11
375	3
376	2
377	1
378	12
379	10"""

# %%
import json
ordering = json.dumps(dict(i.split() for i in maps.splitlines()),indent=2)

# %%
print(ordering)
# Out:
# {
#   "1": "8",
#   "2": "9",
#   "3": "7",
#   "4": "5",
#   "5": "6",
#   "6": "4",
#   "7": "2",
#   "8": "3",
#   "9": "1",
#   "10": "16",
#   "11": "15",
#   "12": "18",
#   "13": "17",
#   "14": "14",
#   "15": "13",
#   "16": "22",
#   "17": "21",
#   "18": "24",
#   "19": "23",
#   "20": "20",
#   "21": "19",
#   "22": "26",
#   "23": "25",
#   "24": "10",
#   "25": "11",
#   "26": "12",
#   "27": "26",
#   "28": "8",
#   "29": "9",
#   "30": "7",
#   "31": "23",
#   "32": "22",
#   "33": "21",
#   "34": "24",
#   "35": "25",
#   "36": "5",
#   "37": "6",
#   "38": "4",
#   "39": "2",
#   "40": "3",
#   "41": "1",
#   "42": "20",
#   "43": "19",
#   "44": "18",
#   "45": "17",
#   "46": "10",
#   "47": "11",
#   "48": "12",
#   "49": "13",
#   "50": "14",
#   "51": "15",
#   "52": "16",
#   "68": "8",
#   "54": "7",
#   "55": "4",
#   "56": "6",
#   "57": "999",
#   "58": "999",
#   "59": "999",
#   "60": "1",
#   "61": "2",
#   "62": "3",
#   "63": "5",
#   "53": "42",
# ...

# %%
items = {
      "team_id": 28637,
      "fixture_id": 16887551,
      "type": "last_25",
      "team": "home",
      "played_home": 2,
      "played_away": 3,
      "played_overall": 5,
      "first_corner_total_avg": 16,
      "first_corner_against_avg": 26.33,
      "first_corner_for_avg": 27,
      "first_goal_total_avg": 26.4,
      "first_goal_against_avg": 39,
      "first_goal_for_avg": 33,
      "goal_timings_for": [57, 90, 54, 68, 82, 4, 17, 79],
      "goal_timings_against": [55, 65, 56, 75, 3, 52, 88, 16, 61, 90],
      "goal_timings_all": [
        57,
        90,
        54,
        68,
        82,
        4,
        17,
        79,
        55,
        65,
        56,
        75,
        3,
        52,
        88,
        16,
        61,
        90
      ],
      "goal_timings_mean": 56.22,
      "corner_timings_for": [37, 50, 90, 1, 45, 43, 60, 63, 83],
      "corner_timings_against": [6, 64, 32, 33, 36, 39, 47, 61, 71, 41, 42, 61],
      "corner_timings_all": [
        37,
        50,
        90,
        1,
        45,
        43,
        60,
        63,
        83,
        6,
        64,
        32,
        33,
        36,
        39,
        47,
        61,
        71,
        41,
        42,
        61
      ],
      "corner_timings_mean": 47.86,
      "won_home": 2,
      "won_away": 0,
      "won_overall": 2,
      "won_home_per": 100,
      "won_away_per": 0,
      "won_overall_per": 40,
      "drawn_home": 0,
      "drawn_away": 0,
      "drawn_overall": 0,
      "drawn_home_per": 0,
      "drawn_away_per": 0,
      "drawn_overall_per": 0,
      "lost_home": 0,
      "lost_away": 3,
      "lost_overall": 3,
      "lost_home_per": 0,
      "lost_away_per": 100,
      "lost_overall_per": 60,
      "fts_home": 0,
      "fts_away": 1,
      "fts_overall": 1,
      "fts_home_per": 0,
      "fts_away_per": 33,
      "fts_overall_per": 20,
      "goal_difference_home": 3,
      "goal_difference_away": -5,
      "goal_difference_overall": -2,
      "btts_home": 2,
      "btts_away": 2,
      "btts_overall": 4,
      "btts_home_per": 100,
      "btts_away_per": 67,
      "btts_overall_per": 80,
      "o05_goals_1h_home": 0,
      "o05_goals_1h_away": 3,
      "o05_goals_1h_overall": 3,
      "o05_goals_1h_home_per": 0,
      "o05_goals_1h_away_per": 100,
      "o05_goals_1h_overall_per": 60,
      "o15_goals_1h_home": 0,
      "o15_goals_1h_away": 1,
      "o15_goals_1h_overall": 1,
      "o15_goals_1h_home_per": 0,
      "o15_goals_1h_away_per": 33,
      "o15_goals_1h_overall_per": 20,
      "o05_goals_2h_home": 2,
      "o05_goals_2h_away": 3,
      "o05_goals_2h_overall": 5,
      "o05_goals_2h_home_per": 100,
      "o05_goals_2h_away_per": 100,
      "o05_goals_2h_overall_per": 100,
      "o15_goals_2h_home": 2,
      "o15_goals_2h_away": 3,
      "o15_goals_2h_overall": 5,
      "o15_goals_2h_home_per": 100,
      "o15_goals_2h_away_per": 100,
      "o15_goals_2h_overall_per": 100,
      "clean_sheets_home": 0,
      "clean_sheets_away": 0,
      "clean_sheets_overall": 0,
      "clean_sheets_home_per": 0,
      "clean_sheets_away_per": 0,
      "clean_sheets_overall_per": 0,
      "o05_goals_home": 2,
      "o05_goals_away": 3,
      "o05_goals_overall": 5,
      "o05_goals_home_per": 100,
      "o05_goals_away_per": 100,
      "o05_goals_overall_per": 100,
      "o15_goals_home": 2,
      "o15_goals_away": 3,
      "o15_goals_overall": 5,
      "o15_goals_home_per": 100,
      "o15_goals_away_per": 100,
      "o15_goals_overall_per": 100,
      "o25_goals_home": 2,
      "o25_goals_away": 3,
      "o25_goals_overall": 5,
      "o25_goals_home_per": 100,
      "o25_goals_away_per": 100,
      "o25_goals_overall_per": 100,
      "o35_goals_home": 1,
      "o35_goals_away": 1,
      "o35_goals_overall": 2,
      "o35_goals_home_per": 50,
      "o35_goals_away_per": 33,
      "o35_goals_overall_per": 40,
      "o55_corners_home": 0,
      "o55_corners_away": 2,
      "o55_corners_overall": 2,
      "o55_corners_home_per": 0,
      "o55_corners_away_per": 67,
      "o55_corners_overall_per": 40,
      "o65_corners_home": 0,
      "o65_corners_away": 2,
      "o65_corners_overall": 2,
      "o65_corners_home_per": 0,
      "o65_corners_away_per": 67,
      "o65_corners_overall_per": 40,
      "o75_corners_home": 0,
      "o75_corners_away": 1,
      "o75_corners_overall": 1,
      "o75_corners_home_per": 0,
      "o75_corners_away_per": 33,
      "o75_corners_overall_per": 20,
      "o85_corners_home": 0,
      "o85_corners_away": 1,
      "o85_corners_overall": 1,
      "o85_corners_home_per": 0,
      "o85_corners_away_per": 33,
      "o85_corners_overall_per": 20,
      "o95_corners_home": 0,
      "o95_corners_away": 0,
      "o95_corners_overall": 0,
      "o95_corners_home_per": 0,
      "o95_corners_away_per": 0,
      "o95_corners_overall_per": 0,
      "o105_corners_home": 0,
      "o105_corners_away": 0,
      "o105_corners_overall": 0,
      "o105_corners_home_per": 0,
      "o105_corners_away_per": 0,
      "o105_corners_overall_per": 0,
      "o115_corners_home": 0,
      "o115_corners_away": 0,
      "o115_corners_overall": 0,
      "o115_corners_home_per": 0,
      "o115_corners_away_per": 0,
      "o115_corners_overall_per": 0,
      "o125_corners_home": 0,
      "o125_corners_away": 0,
      "o125_corners_overall": 0,
      "o125_corners_home_per": 0,
      "o125_corners_away_per": 0,
      "o125_corners_overall_per": 0,
      "o25_cards_home": 1,
      "o25_cards_away": 1,
      "o25_cards_overall": 2,
      "o25_cards_home_per": 50,
      "o25_cards_away_per": 33,
      "o25_cards_overall_per": 40,
      "o35_cards_home": 1,
      "o35_cards_away": 1,
      "o35_cards_overall": 2,
      "o35_cards_home_per": 50,
      "o35_cards_away_per": 33,
      "o35_cards_overall_per": 40,
      "o45_cards_home": 1,
      "o45_cards_away": 1,
      "o45_cards_overall": 2,
      "o45_cards_home_per": 50,
      "o45_cards_away_per": 33,
      "o45_cards_overall_per": 40,
      "o55_cards_home": 1,
      "o55_cards_away": 1,
      "o55_cards_overall": 2,
      "o55_cards_home_per": 50,
      "o55_cards_away_per": 33,
      "o55_cards_overall_per": 40,
      "o65_cards_home": 0,
      "o65_cards_away": 0,
      "o65_cards_overall": 0,
      "o65_cards_home_per": 0,
      "o65_cards_away_per": 0,
      "o65_cards_overall_per": 0,
      "btts_o25_home": 2,
      "btts_o25_away": 2,
      "btts_o25_overall": 4,
      "btts_o25_home_per": 100,
      "btts_o25_away_per": 67,
      "btts_o25_overall_per": 80,
      "o25_corners_1h_home": 0,
      "o25_corners_1h_away": 2,
      "o25_corners_1h_overall": 2,
      "o25_corners_1h_home_per": 0,
      "o25_corners_1h_away_per": 67,
      "o25_corners_1h_overall_per": 40,
      "o35_corners_1h_home": 0,
      "o35_corners_1h_away": 1,
      "o35_corners_1h_overall": 1,
      "o35_corners_1h_home_per": 0,
      "o35_corners_1h_away_per": 33,
      "o35_corners_1h_overall_per": 20,
      "o45_corners_1h_home": 0,
      "o45_corners_1h_away": 1,
      "o45_corners_1h_overall": 1,
      "o45_corners_1h_home_per": 0,
      "o45_corners_1h_away_per": 33,
      "o45_corners_1h_overall_per": 20,
      "o55_corners_1h_home": 0,
      "o55_corners_1h_away": 1,
      "o55_corners_1h_overall": 1,
      "o55_corners_1h_home_per": 0,
      "o55_corners_1h_away_per": 33,
      "o55_corners_1h_overall_per": 20,
      "won_at_ht_home": 0,
      "won_at_ht_away": 1,
      "won_at_ht_overall": 1,
      "won_at_ht_home_per": 0,
      "won_at_ht_away_per": 33,
      "won_at_ht_overall_per": 20,
      "drawn_at_ht_home": 2,
      "drawn_at_ht_away": 1,
      "drawn_at_ht_overall": 3,
      "drawn_at_ht_home_per": 100,
      "drawn_at_ht_away_per": 33,
      "drawn_at_ht_overall_per": 60,
      "lost_at_ht_home": 0,
      "lost_at_ht_away": 1,
      "lost_at_ht_overall": 1,
      "lost_at_ht_home_per": 0,
      "lost_at_ht_away_per": 33,
      "lost_at_ht_overall_per": 20,
      "corners_between_35_45_home": 1,
      "corners_between_35_45_away": 2,
      "corners_between_35_45_overall": 3,
      "corners_between_35_45_home_per": 50,
      "corners_between_35_45_away_per": 67,
      "corners_between_35_45_overall_per": 60,
      "corners_between_80_90_home": 1,
      "corners_between_80_90_away": 1,
      "corners_between_80_90_overall": 2,
      "corners_between_80_90_home_per": 50,
      "corners_between_80_90_away_per": 33,
      "corners_between_80_90_overall_per": 40,
      "goals_between_35_45_home": 0,
      "goals_between_35_45_away": 0,
      "goals_between_35_45_overall": 0,
      "goals_between_35_45_home_per": 0,
      "goals_between_35_45_away_per": 0,
      "goals_between_35_45_overall_per": 0,
      "goals_between_80_90_home": 2,
      "goals_between_80_90_away": 2,
      "goals_between_80_90_overall": 4,
      "goals_between_80_90_home_per": 100,
      "goals_between_80_90_away_per": 67,
      "goals_between_80_90_overall_per": 80,
      "no_goals_home": 0,
      "no_goals_away": 0,
      "no_goals_overall": 0,
      "no_goals_home_per": 0,
      "no_goals_away_per": 0,
      "no_goals_overall_per": 0,
      "no_goals_1h_home": 2,
      "no_goals_1h_away": 0,
      "no_goals_1h_overall": 2,
      "no_goals_1h_home_per": 100,
      "no_goals_1h_away_per": 0,
      "no_goals_1h_overall_per": 40,
      "no_goals_2h_home": 0,
      "no_goals_2h_away": 0,
      "no_goals_2h_overall": 0,
      "no_goals_2h_home_per": 0,
      "no_goals_2h_away_per": 0,
      "no_goals_2h_overall_per": 0,
      "btts_or_o25_home": 2,
      "btts_or_o25_away": 3,
      "btts_or_o25_overall": 5,
      "btts_or_o25_home_per": 100,
      "btts_or_o25_away_per": 100,
      "btts_or_o25_overall_per": 100,
      "goals_between_0_15_home": 0,
      "goals_between_0_15_away": 2,
      "goals_between_0_15_overall": 2,
      "goals_between_0_15_home_per": 0,
      "goals_between_0_15_away_per": 67,
      "goals_between_0_15_overall_per": 40,
      "goals_between_0_15_for_home": 0,
      "goals_between_0_15_for_away": 1,
      "goals_between_0_15_for_overall": 1,
      "goals_between_0_15_for_home_per": 0,
      "goals_between_0_15_for_away_per": 33,
      "goals_between_0_15_for_overall_per": 20,
      "goals_between_0_15_against_home": 0,
      "goals_between_0_15_against_away": 1,
      "goals_between_0_15_against_overall": 1,
      "goals_between_0_15_against_home_per": 0,
      "goals_between_0_15_against_away_per": 33,
      "goals_between_0_15_against_overall_per": 20,
      "corners_between_0_10_home": 1,
      "corners_between_0_10_away": 1,
      "corners_between_0_10_overall": 2,
      "corners_between_0_10_home_per": 50,
      "corners_between_0_10_away_per": 33,
      "corners_between_0_10_overall_per": 40,
      "corners_between_0_10_for_home": 0,
      "corners_between_0_10_for_away": 1,
      "corners_between_0_10_for_overall": 1,
      "corners_between_0_10_for_home_per": 0,
      "corners_between_0_10_for_away_per": 33,
      "corners_between_0_10_for_overall_per": 20,
      "corners_between_0_10_against_home": 1,
      "corners_between_0_10_against_away": 0,
      "corners_between_0_10_against_overall": 1,
      "corners_between_0_10_against_home_per": 50,
      "corners_between_0_10_against_away_per": 0,
      "corners_between_0_10_against_overall_per": 20,
      "scored_o05_home": 2,
      "scored_o05_away": 2,
      "scored_o05_overall": 4,
      "scored_o05_home_per": 100,
      "scored_o05_away_per": 67,
      "scored_o05_overall_per": 80,
      "scored_o15_home": 2,
      "scored_o15_away": 1,
      "scored_o15_overall": 3,
      "scored_o15_home_per": 100,
      "scored_o15_away_per": 33,
      "scored_o15_overall_per": 60,
      "scored_o25_home": 1,
      "scored_o25_away": 0,
      "scored_o25_overall": 1,
      "scored_o25_home_per": 50,
      "scored_o25_away_per": 0,
      "scored_o25_overall_per": 20,
      "scored_o05_1h_home": 0,
      "scored_o05_1h_away": 2,
      "scored_o05_1h_overall": 2,
      "scored_o05_1h_home_per": 0,
      "scored_o05_1h_away_per": 67,
      "scored_o05_1h_overall_per": 40,
      "scored_o15_1h_home": 0,
      "scored_o15_1h_away": 0,
      "scored_o15_1h_overall": 0,
      "scored_o15_1h_home_per": 0,
      "scored_o15_1h_away_per": 0,
      "scored_o15_1h_overall_per": 0,
      "scored_o05_2h_home": 2,
      "scored_o05_2h_away": 1,
      "scored_o05_2h_overall": 3,
      "scored_o05_2h_home_per": 100,
      "scored_o05_2h_away_per": 33,
      "scored_o05_2h_overall_per": 60,
      "scored_o15_2h_home": 2,
      "scored_o15_2h_away": 0,
      "scored_o15_2h_overall": 2,
      "scored_o15_2h_home_per": 100,
      "scored_o15_2h_away_per": 0,
      "scored_o15_2h_overall_per": 40,
      "scored_after_70_home": 2,
      "scored_after_70_away": 1,
      "scored_after_70_overall": 3,
      "scored_after_70_home_per": 100,
      "scored_after_70_away_per": 33,
      "scored_after_70_overall_per": 60,
      "conceded_after_70_home": 0,
      "conceded_after_70_away": 3,
      "conceded_after_70_overall": 3,
      "conceded_after_70_home_per": 0,
      "conceded_after_70_away_per": 100,
      "conceded_after_70_overall_per": 60,
      "goals_after_70_home": 2,
      "goals_after_70_away": 3,
      "goals_after_70_overall": 5,
      "goals_after_70_home_per": 100,
      "goals_after_70_away_per": 100,
      "goals_after_70_overall_per": 100,
      "scored_first_home": 1,
      "scored_first_away": 1,
      "scored_first_overall": 2,
      "scored_first_home_per": 50,
      "scored_first_away_per": 33,
      "scored_first_overall_per": 40,
      "conceded_o05_home": 2,
      "conceded_o05_away": 3,
      "conceded_o05_overall": 5,
      "conceded_o05_home_per": 100,
      "conceded_o05_away_per": 100,
      "conceded_o05_overall_per": 100,
      "conceded_o15_home": 0,
      "conceded_o15_away": 3,
      "conceded_o15_overall": 3,
      "conceded_o15_home_per": 0,
      "conceded_o15_away_per": 100,
      "conceded_o15_overall_per": 60,
      "conceded_o25_home": 0,
      "conceded_o25_away": 2,
      "conceded_o25_overall": 2,
      "conceded_o25_home_per": 0,
      "conceded_o25_away_per": 67,
      "conceded_o25_overall_per": 40,
      "conceded_o05_1h_home": 0,
      "conceded_o05_1h_away": 2,
      "conceded_o05_1h_overall": 2,
      "conceded_o05_1h_home_per": 0,
      "conceded_o05_1h_away_per": 67,
      "conceded_o05_1h_overall_per": 40,
      "conceded_o15_1h_home": 0,
      "conceded_o15_1h_away": 0,
      "conceded_o15_1h_overall": 0,
      "conceded_o15_1h_home_per": 0,
      "conceded_o15_1h_away_per": 0,
      "conceded_o15_1h_overall_per": 0,
      "conceded_o05_2h_home": 2,
      "conceded_o05_2h_away": 3,
      "conceded_o05_2h_overall": 5,
      "conceded_o05_2h_home_per": 100,
      "conceded_o05_2h_away_per": 100,
      "conceded_o05_2h_overall_per": 100,
      "conceded_o15_2h_home": 0,
      "conceded_o15_2h_away": 3,
      "conceded_o15_2h_overall": 3,
      "conceded_o15_2h_home_per": 0,
      "conceded_o15_2h_away_per": 100,
      "conceded_o15_2h_overall_per": 60,
      "btts_1h_home": 0,
      "btts_1h_away": 1,
      "btts_1h_overall": 1,
      "btts_1h_home_per": 0,
      "btts_1h_away_per": 33,
      "btts_1h_overall_per": 20,
      "btts_2h_home": 2,
      "btts_2h_away": 1,
      "btts_2h_overall": 3,
      "btts_2h_home_per": 100,
      "btts_2h_away_per": 33,
      "btts_2h_overall_per": 60,
      "o05_cards_for_home": 1,
      "o05_cards_for_away": 2,
      "o05_cards_for_overall": 3,
      "o05_cards_for_home_per": 50,
      "o05_cards_for_away_per": 67,
      "o05_cards_for_overall_per": 60,
      "o15_cards_for_home": 1,
      "o15_cards_for_away": 2,
      "o15_cards_for_overall": 3,
      "o15_cards_for_home_per": 50,
      "o15_cards_for_away_per": 67,
      "o15_cards_for_overall_per": 60,
      "o25_cards_for_home": 1,
      "o25_cards_for_away": 1,
      "o25_cards_for_overall": 2,
      "o25_cards_for_home_per": 50,
      "o25_cards_for_away_per": 33,
      "o25_cards_for_overall_per": 40,
      "o35_cards_for_home": 0,
      "o35_cards_for_away": 1,
      "o35_cards_for_overall": 1,
      "o35_cards_for_home_per": 0,
      "o35_cards_for_away_per": 33,
      "o35_cards_for_overall_per": 20,
      "o05_cards_for_1h_home": 1,
      "o05_cards_for_1h_away": 0,
      "o05_cards_for_1h_overall": 1,
      "o05_cards_for_1h_home_per": 50,
      "o05_cards_for_1h_away_per": 0,
      "o05_cards_for_1h_overall_per": 20,
      "o15_cards_for_1h_home": 0,
      "o15_cards_for_1h_away": 0,
      "o15_cards_for_1h_overall": 0,
      "o15_cards_for_1h_home_per": 0,
      "o15_cards_for_1h_away_per": 0,
      "o15_cards_for_1h_overall_per": 0,
      "o05_cards_against_1h_home": 0,
      "o05_cards_against_1h_away": 0,
      "o05_cards_against_1h_overall": 0,
      "o05_cards_against_1h_home_per": 0,
      "o05_cards_against_1h_away_per": 0,
      "o05_cards_against_1h_overall_per": 0,
      "o15_cards_against_1h_home": 0,
      "o15_cards_against_1h_away": 0,
      "o15_cards_against_1h_overall": 0,
      "o15_cards_against_1h_home_per": 0,
      "o15_cards_against_1h_away_per": 0,
      "o15_cards_against_1h_overall_per": 0,
      "o05_cards_for_2h_home": 0,
      "o05_cards_for_2h_away": 1,
      "o05_cards_for_2h_overall": 1,
      "o05_cards_for_2h_home_per": 0,
      "o05_cards_for_2h_away_per": 33,
      "o05_cards_for_2h_overall_per": 20,
      "o15_cards_for_2h_home": 0,
      "o15_cards_for_2h_away": 0,
      "o15_cards_for_2h_overall": 0,
      "o15_cards_for_2h_home_per": 0,
      "o15_cards_for_2h_away_per": 0,
      "o15_cards_for_2h_overall_per": 0,
      "o05_cards_against_2h_home": 0,
      "o05_cards_against_2h_away": 0,
      "o05_cards_against_2h_overall": 0,
      "o05_cards_against_2h_home_per": 0,
      "o05_cards_against_2h_away_per": 0,
      "o05_cards_against_2h_overall_per": 0,
      "o15_cards_against_2h_home": 0,
      "o15_cards_against_2h_away": 0,
      "o15_cards_against_2h_overall": 0,
      "o15_cards_against_2h_home_per": 0,
      "o15_cards_against_2h_away_per": 0,
      "o15_cards_against_2h_overall_per": 0,
      "o05_cards_against_home": 1,
      "o05_cards_against_away": 2,
      "o05_cards_against_overall": 3,
      "o05_cards_against_home_per": 50,
      "o05_cards_against_away_per": 67,
      "o05_cards_against_overall_per": 60,
      "o15_cards_against_home": 1,
      "o15_cards_against_away": 1,
      "o15_cards_against_overall": 2,
      "o15_cards_against_home_per": 50,
      "o15_cards_against_away_per": 33,
      "o15_cards_against_overall_per": 40,
      "o25_cards_against_home": 1,
      "o25_cards_against_away": 0,
      "o25_cards_against_overall": 1,
      "o25_cards_against_home_per": 50,
      "o25_cards_against_away_per": 0,
      "o25_cards_against_overall_per": 20,
      "o35_cards_against_home": 0,
      "o35_cards_against_away": 0,
      "o35_cards_against_overall": 0,
      "o35_cards_against_home_per": 0,
      "o35_cards_against_away_per": 0,
      "o35_cards_against_overall_per": 0,
      "points_home": 6,
      "points_away": 0,
      "points_overall": 6,
      "points_home_avg": 3,
      "points_away_avg": 0,
      "points_overall_avg": 1.2,
      "scored_home": 5,
      "scored_away": 3,
      "scored_overall": 8,
      "scored_home_avg": 2.5,
      "scored_away_avg": 1,
      "scored_overall_avg": 1.6,
      "scored_1h_home": 0,
      "scored_1h_away": 2,
      "scored_1h_overall": 2,
      "scored_1h_home_avg": 0,
      "scored_1h_away_avg": 0.67,
      "scored_1h_overall_avg": 0.4,
      "scored_2h_home": 5,
      "scored_2h_away": 1,
      "scored_2h_overall": 6,
      "scored_2h_home_avg": 2.5,
      "scored_2h_away_avg": 0.33,
      "scored_2h_overall_avg": 1.2,
      "conceded_home": 2,
      "conceded_away": 8,
      "conceded_overall": 10,
      "conceded_home_avg": 1,
      "conceded_away_avg": 2.67,
      "conceded_overall_avg": 2,
      "conceded_1h_home": 0,
      "conceded_1h_away": 2,
      "conceded_1h_overall": 2,
      "conceded_1h_home_avg": 0,
      "conceded_1h_away_avg": 0.67,
      "conceded_1h_overall_avg": 0.4,
      "conceded_2h_home": 2,
      "conceded_2h_away": 6,
      "conceded_2h_overall": 8,
      "conceded_2h_home_avg": 1,
      "conceded_2h_away_avg": 2,
      "conceded_2h_overall_avg": 1.6,
      "corners_for_home": 3,
      "corners_for_away": 6,
      "corners_for_overall": 9,
      "corners_for_home_avg": 1.5,
      "corners_for_away_avg": 2,
      "corners_for_overall_avg": 1.8,
      "corners_against_home": 2,
      "corners_against_away": 10,
      "corners_against_overall": 12,
      "corners_against_home_avg": 1,
      "corners_against_away_avg": 3.33,
      "corners_against_overall_avg": 2.4,
      "cards_for_home": 3,
      "cards_for_away": 6,
      "cards_for_overall": 9,
      "cards_for_home_avg": 1.5,
      "cards_for_away_avg": 2,
      "cards_for_overall_avg": 1.8,
      "cards_against_home": 3,
      "cards_against_away": 3,
      "cards_against_overall": 6,
      "cards_against_home_avg": 1.5,
      "cards_against_away_avg": 1,
      "cards_against_overall_avg": 1.2,
      "cards_total_home": 6,
      "cards_total_away": 9,
      "cards_total_overall": 15,
      "cards_total_home_avg": 3,
      "cards_total_away_avg": 3,
      "cards_total_overall_avg": 3,
      "cards_for_1h_home": 1,
      "cards_for_1h_away": 0,
      "cards_for_1h_overall": 1,
      "cards_for_1h_home_avg": 0.5,
      "cards_for_1h_away_avg": 0,
      "cards_for_1h_overall_avg": 0.2,
      "cards_against_1h_home": 0,
      "cards_against_1h_away": 0,
      "cards_against_1h_overall": 0,
      "cards_against_1h_home_avg": 0,
      "cards_against_1h_away_avg": 0,
      "cards_against_1h_overall_avg": 0,
      "cards_total_1h_home": 1,
      "cards_total_1h_away": 0,
      "cards_total_1h_overall": 1,
      "cards_total_1h_home_avg": 0.5,
      "cards_total_1h_away_avg": 0,
      "cards_total_1h_overall_avg": 0.2,
      "cards_for_2h_home": 0,
      "cards_for_2h_away": 1,
      "cards_for_2h_overall": 1,
      "cards_for_2h_home_avg": 0,
      "cards_for_2h_away_avg": 0.33,
      "cards_for_2h_overall_avg": 0.2,
      "cards_against_2h_home": 0,
      "cards_against_2h_away": 0,
      "cards_against_2h_overall": 0,
      "cards_against_2h_home_avg": 0,
      "cards_against_2h_away_avg": 0,
      "cards_against_2h_overall_avg": 0,
      "cards_total_2h_home": 0,
      "cards_total_2h_away": 1,
      "cards_total_2h_overall": 1,
      "cards_total_2h_home_avg": 0,
      "cards_total_2h_away_avg": 0.33,
      "cards_total_2h_overall_avg": 0.2,
      "corners_for_1h_home": 1,
      "corners_for_1h_away": 3,
      "corners_for_1h_overall": 4,
      "corners_for_1h_home_avg": 0.5,
      "corners_for_1h_away_avg": 1,
      "corners_for_1h_overall_avg": 0.8,
      "corners_against_1h_home": 1,
      "corners_against_1h_away": 6,
      "corners_against_1h_overall": 7,
      "corners_against_1h_home_avg": 0.5,
      "corners_against_1h_away_avg": 2,
      "corners_against_1h_overall_avg": 1.4,
      "corners_total_1h_home": 2,
      "corners_total_1h_away": 9,
      "corners_total_1h_overall": 11,
      "corners_total_1h_home_avg": 1,
      "corners_total_1h_away_avg": 3,
      "corners_total_1h_overall_avg": 2.2,
      "corners_for_2h_home": 2,
      "corners_for_2h_away": 3,
      "corners_for_2h_overall": 5,
      "corners_for_2h_home_avg": 1,
      "corners_for_2h_away_avg": 1,
      "corners_for_2h_overall_avg": 1,
      "corners_against_2h_home": 1,
      "corners_against_2h_away": 4,
      "corners_against_2h_overall": 5,
      "corners_against_2h_home_avg": 0.5,
      "corners_against_2h_away_avg": 1.33,
      "corners_against_2h_overall_avg": 1,
      "corners_total_2h_home": 3,
      "corners_total_2h_away": 7,
      "corners_total_2h_overall": 10,
      "corners_total_2h_home_avg": 1.5,
      "corners_total_2h_away_avg": 2.33,
      "corners_total_2h_overall_avg": 2,
      "corners_total_home": 5,
      "corners_total_away": 16,
      "corners_total_overall": 21,
      "corners_total_home_avg": 2.5,
      "corners_total_away_avg": 5.33,
      "corners_total_overall_avg": 4.2,
      "total_goals_home": 7,
      "total_goals_away": 11,
      "total_goals_overall": 18,
      "total_goals_home_avg": 3.5,
      "total_goals_away_avg": 3.67,
      "total_goals_overall_avg": 3.6
    }

# %%
for i in items:
  print(i)
# Out:
# team_id
# fixture_id
# type
# team
# played_home
# played_away
# played_overall
# first_corner_total_avg
# first_corner_against_avg
# first_corner_for_avg
# first_goal_total_avg
# first_goal_against_avg
# first_goal_for_avg
# goal_timings_for
# goal_timings_against
# goal_timings_all
# goal_timings_mean
# corner_timings_for
# corner_timings_against
# corner_timings_all
# corner_timings_mean
# won_home
# won_away
# won_overall
# won_home_per
# won_away_per
# won_overall_per
# drawn_home
# drawn_away
# drawn_overall
# drawn_home_per
# drawn_away_per
# drawn_overall_per
# lost_home
# lost_away
# lost_overall
# lost_home_per
# lost_away_per
# lost_overall_per
# fts_home
# fts_away
# fts_overall
# fts_home_per
# fts_away_per
# fts_overall_per
# goal_difference_home
# goal_difference_away
# goal_difference_overall
# btts_home
# btts_away
# btts_overall
# btts_home_per
# btts_away_per
# btts_overall_per
# o05_goals_1h_home
# o05_goals_1h_away
# o05_goals_1h_overall
# o05_goals_1h_home_per
# ...

# %%
items = {
	"data":
	[
		{
			"code": "away_win",
			"label": "Away Win"
		},
		{
			"code": "away_win_ht",
			"label": "Away Win [HT]"
		},
		{
			"code": "away_win_or_draw",
			"label": "Double Chance [Draw Away] (2X)"
		},
		{
			"code": "btts",
			"label": "Both Teams to Score (Yes)"
		},
		{
			"code": "btts_1h",
			"label": "Both Teams to Score in 1st Half (Yes)"
		},
		{
			"code": "btts_1h_no",
			"label": "Both Teams to Score in 1st Half (No)"
		},
		{
			"code": "btts_2h",
			"label": "Both Teams to Score in 2nd Half (Yes)"
		},
		{
			"code": "btts_2h_no",
			"label": "Both Teams to Score in 2nd Half (No)"
		},
		{
			"code": "btts_no",
			"label": "Both Teams to Score (No)"
		},
		{
			"code": "dnb",
			"label": "Draw No Bet"
		},
		{
			"code": "dnb_away",
			"label": "Draw No Bet [Away] (2)"
		},
		{
			"code": "draw",
			"label": "Draw"
		},
		{
			"code": "draw_ht",
			"label": "Draw [HT]"
		},
		{
			"code": "e10_corners",
			"label": "Exactly 10 Total Corners"
		},
		{
			"code": "e11_corners",
			"label": "Exactly 11 Total Corners"
		},
		{
			"code": "e12_corners",
			"label": "Exactly 12 Total Corners"
		},
		{
			"code": "e7_corners",
			"label": "Exactly 7 Total Corners"
		},
		{
			"code": "e8_corners",
			"label": "Exactly 8 Total Corners"
		},
		{
			"code": "e9_corners",
			"label": "Exactly 9 Total Corners"
		},
		{
			"code": "home_win",
			"label": "Home Win"
		},
		{
			"code": "home_win_ht",
			"label": "Home Win [HT]"
		},
		{
			"code": "home_win_or_away_win",
			"label": "Double Chance [Home Away] (12)"
		},
		{
			"code": "home_win_or_draw",
			"label": "Double Chance [Home Draw] (1X)"
		},
		{
			"code": "o05_asian_corners",
			"label": "Over 0.5 Asian Corners"
		},
		{
			"code": "o05_asian_corners_1h",
			"label": "Over 0.5 Asian Corners (1st Half)"
		},
		{
			"code": "o05_goal_line_1h",
			"label": "Over 0.5 Goal Line (1st Half)"
		},
		{
			"code": "o05_goals",
			"label": "Match Goals Over 0.5"
		},
		{
			"code": "o05_goals_1h",
			"label": "1st Half Goals Over 0.5"
		},
		{
			"code": "o105_asian_corners",
			"label": "Over 10.5 Asian Corners"
		},
		{
			"code": "o105_asian_corners_1h",
			"label": "Over 10.5 Asian Corners (1st Half)"
		},
		{
			"code": "o10_asian_corners",
			"label": "Over 10 Asian Corners"
		},
		{
			"code": "o10_asian_corners_1h",
			"label": "Over 10 Asian Corners (1st Half)"
		},
		{
			"code": "o10_corners",
			"label": "Over 10 Total Corners"
		},
		{
			"code": "o10_goal_line_1h",
			"label": "Over 1.0 Goal Line (1st Half)"
		},
		{
			"code": "o115_asian_corners",
			"label": "Over 11.5 Asian Corners"
		},
		{
			"code": "o115_asian_corners_1h",
			"label": "Over 11.5 Asian Corners (1st Half)"
		},
		{
			"code": "o11_asian_corners",
			"label": "Over 11 Asian Corners"
		},
		{
			"code": "o11_asian_corners_1h",
			"label": "Over 11 Asian Corners (1st Half)"
		},
		{
			"code": "o11_corners",
			"label": "Over 11 Total Corners"
		},
		{
			"code": "o125_asian_corners",
			"label": "Over 12.5 Asian Corners"
		},
		{
			"code": "o125_asian_corners_1h",
			"label": "Over 12.5 Asian Corners (1st Half)"
		},
		{
			"code": "o12_asian_corners",
			"label": "Over 12 Asian Corners"
		},
		{
			"code": "o12_asian_corners_1h",
			"label": "Over 12 Asian Corners (1st Half)"
		},
		{
			"code": "o12_corners",
			"label": "Over 12 Total Corners"
		},
		{
			"code": "o135_asian_corners",
			"label": "Over 13.5 Asian Corners"
		},
		{
			"code": "o135_asian_corners_1h",
			"label": "Over 13.5 Asian Corners (1st Half)"
		},
		{
			"code": "o13_asian_corners",
			"label": "Over 13 Asian Corners"
		},
		{
			"code": "o13_asian_corners_1h",
			"label": "Over 13 Asian Corners (1st Half)"
		},
		{
			"code": "o145_asian_corners",
			"label": "Over 14.5 Asian Corners"
		},
		{
			"code": "o145_asian_corners_1h",
			"label": "Over 14.5 Asian Corners (1st Half)"
		},
		{
			"code": "o14_asian_corners",
			"label": "Over 14 Asian Corners"
		},
		{
			"code": "o14_asian_corners_1h",
			"label": "Over 14 Asian Corners (1st Half)"
		},
		{
			"code": "o155_asian_corners",
			"label": "Over 15.5 Asian Corners"
		},
		{
			"code": "o15_asian_corners",
			"label": "Over 15 Asian Corners"
		},
		{
			"code": "o15_asian_corners_1h",
			"label": "Over 15 Asian Corners (1st Half)"
		},
		{
			"code": "o15_goal_line",
			"label": "Over 1.5 Goal Line"
		},
		{
			"code": "o15_goals",
			"label": "Match Goals Over 1.5"
		},
		{
			"code": "o15_goals_1h",
			"label": "1st Half Goals Over 1.5"
		},
		{
			"code": "o165_asian_corners",
			"label": "Over 16.5 Asian Corners"
		},
		{
			"code": "o16_asian_corners",
			"label": "Over 16 Asian Corners"
		},
		{
			"code": "o175_asian_corners",
			"label": "Over 17.5 Asian Corners"
		},
		{
			"code": "o17_asian_corners",
			"label": "Over 17 Asian Corners"
		},
		{
			"code": "o185_asian_corners",
			"label": "Over 18.5 Asian Corners"
		},
		{
			"code": "o18_asian_corners",
			"label": "Over 18 Asian Corners"
		},
		{
			"code": "o195_asian_corners",
			"label": "Over 19.5 Asian Corners"
		},
		{
			"code": "o19_asian_corners",
			"label": "Over 19 Asian Corners"
		},
		{
			"code": "o1_asian_corners",
			"label": "Over 1 Asian Corners"
		},
		{
			"code": "o1_asian_corners_1h",
			"label": "Over 1 Asian Corners (1st Half)"
		},
		{
			"code": "o205_asian_corners",
			"label": "Over 20.5 Asian Corners"
		},
		{
			"code": "o20_asian_corners",
			"label": "Over 20 Asian Corners"
		},
		{
			"code": "o20_goal_line",
			"label": "Over 2.0 Goal Line"
		},
		{
			"code": "o215_asian_corners",
			"label": "Over 21.5 Asian Corners"
		},
		{
			"code": "o21_asian_corners",
			"label": "Over 21 Asian Corners"
		},
		{
			"code": "o225_asian_corners",
			"label": "Over 22.5 Asian Corners"
		},
		{
			"code": "o22_asian_corners",
			"label": "Over 22 Asian Corners"
		},
		{
			"code": "o235_asian_corners",
			"label": "Over 23.5 Asian Corners"
		},
		{
			"code": "o23_asian_corners",
			"label": "Over 23 Asian Corners"
		},
		{
			"code": "o245_asian_corners",
			"label": "Over 24.5 Asian Corners"
		},
		{
			"code": "o24_asian_corners",
			"label": "Over 24 Asian Corners"
		},
		{
			"code": "o25_asian_corners",
			"label": "Over 25 Asian Corners"
		},
		{
			"code": "o25_asian_corners_1h",
			"label": "Over 2.5 Asian Corners (1st Half)"
		},
		{
			"code": "o25_goal_line",
			"label": "Over 2.5 Goal Line"
		},
		{
			"code": "o25_goals",
			"label": "Match Goals Over 2.5"
		},
		{
			"code": "o25_goals_1h",
			"label": "1st Half Goals Over 2.5"
		},
		{
			"code": "o2_asian_corners",
			"label": "Over 2 Asian Corners"
		},
		{
			"code": "o2_asian_corners_1h",
			"label": "Over 2 Asian Corners (1st Half)"
		},
		{
			"code": "o35_asian_corners",
			"label": "Over 3.5 Asian Corners"
		},
		{
			"code": "o35_asian_corners_1h",
			"label": "Over 3.5 Asian Corners (1st Half)"
		},
		{
			"code": "o35_goals",
			"label": "Match Goals Over 3.5"
		},
		{
			"code": "o35_goals_1h",
			"label": "1st Half Goals Over 3.5"
		},
		{
			"code": "o3_asian_corners",
			"label": "Over 3 Asian Corners"
		},
		{
			"code": "o3_asian_corners_1h",
			"label": "Over 3 Asian Corners (1st Half)"
		},
		{
			"code": "o45_asian_corners",
			"label": "Over 4.5 Asian Corners"
		},
		{
			"code": "o45_asian_corners_1h",
			"label": "Over 4.5 Asian Corners (1st Half)"
		},
		{
			"code": "o45_goals",
			"label": "Match Goals Over 4.5"
		},
		{
			"code": "o45_goals_1h",
			"label": "1st Half Goals Over 4.5"
		},
		{
			"code": "o4_asian_corners",
			"label": "Over 4 Asian Corners"
		},
		{
			"code": "o4_asian_corners_1h",
			"label": "Over 4 Asian Corners (1st Half)"
		},
		{
			"code": "o55_asian_corners",
			"label": "Over 5.5 Asian Corners"
		},
		{
			"code": "o55_asian_corners_1h",
			"label": "Over 5.5 Asian Corners (1st Half)"
		},
		{
			"code": "o55_goals",
			"label": "Match Goals Over 5.5"
		},
		{
			"code": "o55_goals_1h",
			"label": "1st Half Goals Over 5.5"
		},
		{
			"code": "o5_asian_corners",
			"label": "Over 5 Asian Corners"
		},
		{
			"code": "o5_asian_corners_1h",
			"label": "Over 5 Asian Corners (1st Half)"
		},
		{
			"code": "o65_asian_corners",
			"label": "Over 6.5 Asian Corners"
		},
		{
			"code": "o65_asian_corners_1h",
			"label": "Over 6.5 Asian Corners (1st Half)"
		},
		{
			"code": "o65_goals",
			"label": "Match Goals Over 6.5"
		},
		{
			"code": "o6_asian_corners",
			"label": "Over 6 Asian Corners"
		},
		{
			"code": "o6_asian_corners_1h",
			"label": "Over 6 Asian Corners (1st Half)"
		},
		{
			"code": "o75_asian_corners",
			"label": "Over 7.5 Asian Corners"
		},
		{
			"code": "o75_asian_corners_1h",
			"label": "Over 7.5 Asian Corners (1st Half)"
		},
		{
			"code": "o75_goals",
			"label": "Match Goals Over 7.5"
		},
		{
			"code": "o7_asian_corners",
			"label": "Over 7 Asian Corners"
		},
		{
			"code": "o7_asian_corners_1h",
			"label": "Over 7 Asian Corners (1st Half)"
		},
		{
			"code": "o7_corners",
			"label": "Over 7 Total Corners"
		},
		{
			"code": "o85_asian_corners",
			"label": "Over 8.5 Asian Corners"
		},
		{
			"code": "o85_asian_corners_1h",
			"label": "Over 8.5 Asian Corners (1st Half)"
		},
		{
			"code": "o85_goals",
			"label": "Match Goals Over 8.5"
		},
		{
			"code": "o8_asian_corners",
			"label": "Over 8 Asian Corners"
		},
		{
			"code": "o8_asian_corners_1h",
			"label": "Over 8 Asian Corners (1st Half)"
		},
		{
			"code": "o8_corners",
			"label": "Over 8 Total Corners"
		},
		{
			"code": "o95_asian_corners",
			"label": "Over 9.5 Asian Corners"
		},
		{
			"code": "o95_asian_corners_1h",
			"label": "Over 9.5 Asian Corners (1st Half)"
		},
		{
			"code": "o9_asian_corners",
			"label": "Over 9 Asian Corners"
		},
		{
			"code": "o9_asian_corners_1h",
			"label": "Over 9 Asian Corners (1st Half)"
		},
		{
			"code": "o9_corners",
			"label": "Over 9 Total Corners"
		},
		{
			"code": "u05_asian_corners",
			"label": "Under 0.5 Asian Corners"
		},
		{
			"code": "u05_asian_corners_1h",
			"label": "Under 0.5 Asian Corners (1st Half)"
		},
		{
			"code": "u05_goal_line_1h",
			"label": "Under 0.5 Goal Line (1st Half)"
		},
		{
			"code": "u05_goals",
			"label": "Match Goals Under 0.5"
		},
		{
			"code": "u05_goals_1h",
			"label": "1st Half Goals Under 0.5"
		},
		{
			"code": "u105_asian_corners",
			"label": "Under 10.5 Asian Corners"
		},
		{
			"code": "u105_asian_corners_1h",
			"label": "Under 10.5 Asian Corners (1st Half)"
		},
		{
			"code": "u10_asian_corners",
			"label": "Under 10 Asian Corners"
		},
		{
			"code": "u10_asian_corners_1h",
			"label": "Under 10 Asian Corners (1st Half)"
		},
		{
			"code": "u10_corners",
			"label": "Under 10 Total Corners"
		},
		{
			"code": "u10_goal_line_1h",
			"label": "Under 1.0 Goal Line (1st Half)"
		},
		{
			"code": "u115_asian_corners",
			"label": "Under 11.5 Asian Corners"
		},
		{
			"code": "u115_asian_corners_1h",
			"label": "Under 11.5 Asian Corners (1st Half)"
		},
		{
			"code": "u11_asian_corners",
			"label": "Under 11 Asian Corners"
		},
		{
			"code": "u11_asian_corners_1h",
			"label": "Under 11 Asian Corners (1st Half)"
		},
		{
			"code": "u11_corners",
			"label": "Under 11 Total Corners"
		},
		{
			"code": "u125_asian_corners",
			"label": "Under 12.5 Asian Corners"
		},
		{
			"code": "u125_asian_corners_1h",
			"label": "Under 12.5 Asian Corners (1st Half)"
		},
		{
			"code": "u12_asian_corners",
			"label": "Under 12 Asian Corners"
		},
		{
			"code": "u12_asian_corners_1h",
			"label": "Under 12 Asian Corners (1st Half)"
		},
		{
			"code": "u12_corners",
			"label": "Under 12 Total Corners"
		},
		{
			"code": "u135_asian_corners",
			"label": "Under 13.5 Asian Corners"
		},
		{
			"code": "u135_asian_corners_1h",
			"label": "Under 13.5 Asian Corners (1st Half)"
		},
		{
			"code": "u13_asian_corners",
			"label": "Under 13 Asian Corners"
		},
		{
			"code": "u13_asian_corners_1h",
			"label": "Under 13 Asian Corners (1st Half)"
		},
		{
			"code": "u145_asian_corners",
			"label": "Under 14.5 Asian Corners"
		},
		{
			"code": "u145_asian_corners_1h",
			"label": "Under 14.5 Asian Corners (1st Half)"
		},
		{
			"code": "u14_asian_corners",
			"label": "Under 14 Asian Corners"
		},
		{
			"code": "u14_asian_corners_1h",
			"label": "Under 14 Asian Corners (1st Half)"
		},
		{
			"code": "u155_asian_corners",
			"label": "Under 15.5 Asian Corners"
		},
		{
			"code": "u15_asian_corners",
			"label": "Under 15 Asian Corners"
		},
		{
			"code": "u15_asian_corners_1h",
			"label": "Under 15 Asian Corners (1st Half)"
		},
		{
			"code": "u15_goal_line",
			"label": "Under 1.5 Goal Line"
		},
		{
			"code": "u15_goals",
			"label": "Match Goals Under 1.5"
		},
		{
			"code": "u15_goals_1h",
			"label": "1st Half Goals Under 1.5"
		},
		{
			"code": "u165_asian_corners",
			"label": "Under 16.5 Asian Corners"
		},
		{
			"code": "u16_asian_corners",
			"label": "Under 16 Asian Corners"
		},
		{
			"code": "u175_asian_corners",
			"label": "Under 17.5 Asian Corners"
		},
		{
			"code": "u17_asian_corners",
			"label": "Under 17 Asian Corners"
		},
		{
			"code": "u185_asian_corners",
			"label": "Under 18.5 Asian Corners"
		},
		{
			"code": "u18_asian_corners",
			"label": "Under 18 Asian Corners"
		},
		{
			"code": "u195_asian_corners",
			"label": "Under 19.5 Asian Corners"
		},
		{
			"code": "u19_asian_corners",
			"label": "Under 19 Asian Corners"
		},
		{
			"code": "u1_asian_corners",
			"label": "Under 1 Asian Corners"
		},
		{
			"code": "u1_asian_corners_1h",
			"label": "Under 1 Asian Corners (1st Half)"
		},
		{
			"code": "u205_asian_corners",
			"label": "Under 20.5 Asian Corners"
		},
		{
			"code": "u20_asian_corners",
			"label": "Under 20 Asian Corners"
		},
		{
			"code": "u20_goal_line",
			"label": "Under 2.0 Goal Line"
		},
		{
			"code": "u215_asian_corners",
			"label": "Under 21.5 Asian Corners"
		},
		{
			"code": "u21_asian_corners",
			"label": "Under 21 Asian Corners"
		},
		{
			"code": "u225_asian_corners",
			"label": "Under 22.5 Asian Corners"
		},
		{
			"code": "u22_asian_corners",
			"label": "Under 22 Asian Corners"
		},
		{
			"code": "u235_asian_corners",
			"label": "Under 23.5 Asian Corners"
		},
		{
			"code": "u23_asian_corners",
			"label": "Under 23 Asian Corners"
		},
		{
			"code": "u245_asian_corners",
			"label": "Under 24.5 Asian Corners"
		},
		{
			"code": "u24_asian_corners",
			"label": "Under 24 Asian Corners"
		},
		{
			"code": "u25_asian_corners",
			"label": "Under 25 Asian Corners"
		},
		{
			"code": "u25_asian_corners_1h",
			"label": "Under 2.5 Asian Corners (1st Half)"
		},
		{
			"code": "u25_goal_line",
			"label": "Under 2.5 Goal Line"
		},
		{
			"code": "u25_goals",
			"label": "Match Goals Under 2.5"
		},
		{
			"code": "u25_goals_1h",
			"label": "1st Half Goals Under 2.5"
		},
		{
			"code": "u2_asian_corners",
			"label": "Under 2 Asian Corners"
		},
		{
			"code": "u2_asian_corners_1h",
			"label": "Under 2 Asian Corners (1st Half)"
		},
		{
			"code": "u35_asian_corners",
			"label": "Under 3.5 Asian Corners"
		},
		{
			"code": "u35_asian_corners_1h",
			"label": "Under 3.5 Asian Corners (1st Half)"
		},
		{
			"code": "u35_goals",
			"label": "Match Goals Under 3.5"
		},
		{
			"code": "u35_goals_1h",
			"label": "1st Half Goals Under 3.5"
		},
		{
			"code": "u3_asian_corners",
			"label": "Under 3 Asian Corners"
		},
		{
			"code": "u3_asian_corners_1h",
			"label": "Under 3 Asian Corners (1st Half)"
		},
		{
			"code": "u45_asian_corners",
			"label": "Under 4.5 Asian Corners"
		},
		{
			"code": "u45_asian_corners_1h",
			"label": "Under 4.5 Asian Corners (1st Half)"
		},
		{
			"code": "u45_goals",
			"label": "Match Goals Under 4.5"
		},
		{
			"code": "u45_goals_1h",
			"label": "1st Half Goals Under 4.5"
		},
		{
			"code": "u4_asian_corners",
			"label": "Under 4 Asian Corners"
		},
		{
			"code": "u4_asian_corners_1h",
			"label": "Under 4 Asian Corners (1st Half)"
		},
		{
			"code": "u55_asian_corners",
			"label": "Under 5.5 Asian Corners"
		},
		{
			"code": "u55_asian_corners_1h",
			"label": "Under 5.5 Asian Corners (1st Half)"
		},
		{
			"code": "u55_goals",
			"label": "Match Goals Under 5.5"
		},
		{
			"code": "u55_goals_1h",
			"label": "1st Half Goals Under 5.5"
		},
		{
			"code": "u5_asian_corners",
			"label": "Under 5 Asian Corners"
		},
		{
			"code": "u5_asian_corners_1h",
			"label": "Under 5 Asian Corners (1st Half)"
		},
		{
			"code": "u65_asian_corners",
			"label": "Under 6.5 Asian Corners"
		},
		{
			"code": "u65_asian_corners_1h",
			"label": "Under 6.5 Asian Corners (1st Half)"
		},
		{
			"code": "u65_goals",
			"label": "Match Goals Under 6.5"
		},
		{
			"code": "u6_asian_corners",
			"label": "Under 6 Asian Corners"
		},
		{
			"code": "u6_asian_corners_1h",
			"label": "Under 6 Asian Corners (1st Half)"
		},
		{
			"code": "u75_asian_corners",
			"label": "Under 7.5 Asian Corners"
		},
		{
			"code": "u75_asian_corners_1h",
			"label": "Under 7.5 Asian Corners (1st Half)"
		},
		{
			"code": "u75_goals",
			"label": "Match Goals Under 7.5"
		},
		{
			"code": "u7_asian_corners",
			"label": "Under 7 Asian Corners"
		},
		{
			"code": "u7_asian_corners_1h",
			"label": "Under 7 Asian Corners (1st Half)"
		},
		{
			"code": "u7_corners",
			"label": "Under 7 Total Corners"
		},
		{
			"code": "u85_asian_corners",
			"label": "Under 8.5 Asian Corners"
		},
		{
			"code": "u85_asian_corners_1h",
			"label": "Under 8.5 Asian Corners (1st Half)"
		},
		{
			"code": "u85_goals",
			"label": "Match Goals Under 8.5"
		},
		{
			"code": "u8_asian_corners",
			"label": "Under 8 Asian Corners"
		},
		{
			"code": "u8_asian_corners_1h",
			"label": "Under 8 Asian Corners (1st Half)"
		},
		{
			"code": "u8_corners",
			"label": "Under 8 Total Corners"
		},
		{
			"code": "u95_asian_corners",
			"label": "Under 9.5 Asian Corners"
		},
		{
			"code": "u95_asian_corners_1h",
			"label": "Under 9.5 Asian Corners (1st Half)"
		},
		{
			"code": "u9_asian_corners",
			"label": "Under 9 Asian Corners"
		},
		{
			"code": "u9_asian_corners_1h",
			"label": "Under 9 Asian Corners (1st Half)"
		},
		{
			"code": "u9_corners",
			"label": "Under 9 Total Corners"
		},
		{
			"code": "win",
			"label": "Full Time Result [1X2]"
		},
		{
			"code": "win_ht",
			"label": "Half Time Result [1X2]"
		}
	]
}

# %%
for item in items["data"]:
  print(item['code'], item['label'], sep="\t")
# Out:
# away_win	Away Win
# away_win_ht	Away Win [HT]
# away_win_or_draw	Double Chance [Draw Away] (2X)
# btts	Both Teams to Score (Yes)
# btts_1h	Both Teams to Score in 1st Half (Yes)
# btts_1h_no	Both Teams to Score in 1st Half (No)
# btts_2h	Both Teams to Score in 2nd Half (Yes)
# btts_2h_no	Both Teams to Score in 2nd Half (No)
# btts_no	Both Teams to Score (No)
# dnb	Draw No Bet
# dnb_away	Draw No Bet [Away] (2)
# draw	Draw
# draw_ht	Draw [HT]
# e10_corners	Exactly 10 Total Corners
# e11_corners	Exactly 11 Total Corners
# e12_corners	Exactly 12 Total Corners
# e7_corners	Exactly 7 Total Corners
# e8_corners	Exactly 8 Total Corners
# e9_corners	Exactly 9 Total Corners
# home_win	Home Win
# home_win_ht	Home Win [HT]
# home_win_or_away_win	Double Chance [Home Away] (12)
# home_win_or_draw	Double Chance [Home Draw] (1X)
# o05_asian_corners	Over 0.5 Asian Corners
# o05_asian_corners_1h	Over 0.5 Asian Corners (1st Half)
# o05_goal_line_1h	Over 0.5 Goal Line (1st Half)
# ...

# %%
lines = """"id";"title";"description";"roi";"video_embed";"video_description";"learn";"active";"created_at";"updated_at"
"2";"The £100 to £500,000 Compound System 🤑";"Albert Einstein once said “Compound interest is the eighth wonder of the world. He who understands it, earns it … he who doesn't … pays it” . This betting system follows the compound interest concept. ";"300";"<div style=\"padding:56.25% 0 0 0;position:relative;\"><iframe src=\"https://player.vimeo.com/video/640300645?h=37a894417d&amp;badge=0&amp;autopause=0&amp;player_id=0&amp;app_id=58479\" frameborder=\"0\" allow=\"autoplay; fullscreen; picture-in-picture\" allowfullscreen style=\"position:absolute;top:0;left:0;width:100%;height:100%;\" title=\"Footy Amigo Final HD.mp4\"></iframe></div><script src=\"https://player.vimeo.com/api/player.js\"></script>";"This system follows setting aside a betting bank (£100 for example and building it to over £500,000 in 90days) by betting smart on small odds and compounding your profits daily. The video above explains the system and you also have corresponding preset st";"You will be learning a compound interest betting system that involves betting increasing your bet bank by only 10% per day betting on games with 99% chance of winning. ";"1";"2021-10-29 07:13:15";"2021-10-30 10:12:03"
"5";"Over 1.5 Goals at 2.0 Odds System 🔥";"For this sytem, we will be playing it very smart by leveraging the same technology the bookies use to gain edge, against them. You will see how to place your bets at a specific time of a match.  The hard work has been done for you. Follow this system, and";"200";"
<div style=\"padding:56.25% 0 0 0;position:relative;\"><iframe src=\"https://player.vimeo.com/video/640300645?h=37a894417d&amp;badge=0&amp;autopause=0&amp;player_id=0&amp;app_id=58479\" frameborder=\"0\" allow=\"autoplay; fullscreen; picture-in-picture\" allowfullscreen style=\"position:absolute;top:0;left:0;width:100%;height:100%;\" title=\"Footy Amigo Final HD.mp4\"></iframe></div><script src=\"https://player.vimeo.com/api/player.js\"></script>";"This system involves placing your bets at the 30th minute of a live match with a current score line of 0-0. But that's not all, You will be combining the power of InPlay alerts with PreMatch stats for added leverage, all this is explained indepth in the v";"You will be learning a simple, yet profitable betting system for placing Over 1.5 Goals Bets with odds ranging from 1.65, 1.7, 1.8 up to 2.0. Watch the video to know more. ";"1";"2021-10-29 09:54:06";"2021-10-30 10:13:12"
"6";"1 More Goal To Be Scored System ⚽";"Just as the name implies - the \"1 more goal to be scored sytem\" is a very interesting betting system where you will be placing bets that 1 more goal will be scored in the 2nd half of a Match. Using the accompanied strategy presets attached to this system,";"500";"<div style=\"padding:56.25% 0 0 0;position:relative;\"><iframe src=\"https://player.vimeo.com/video/640300645?h=37a894417d&amp;badge=0&amp;autopause=0&amp;player_id=0&amp;app_id=58479\" frameborder=\"0\" allow=\"autoplay; fullscreen; picture-in-picture\" allowfullscreen style=\"position:absolute;top:0;left:0;width:100%;height:100%;\" title=\"Footy Amigo Final HD.mp4\"></iframe></div><script src=\"https://player.vimeo.com/api/player.js\"></script>";"This system involves placing your bet at Half Time of a live match where the score line is 1-1. The idea behind this system is that - given certain conditions (such as shots on target, goals scored, PreMatch Stats, etc) during 1st half, there will be 1 or";"You will be learning a simple, yet profitable betting system for placing bets on 1 more goal to be scored in 2nd half at odds 1.5, 1.7 or even 2.0. Watch the video to know more. ";"1";"2021-10-29 10:10:57";"2021-10-30 10:14:09"
"7";"The Late Cheeky Corner System 😱";"In this system, we will be focusing on corners, specifically the total corners of a match but with a twist! We will look at the Live and Prematch Stats that must be met for us to find and bet on profitable games at Odds 1.7, 1.8, 2.0 or more! This is an i";"250";"<div style=\"padding:56.25% 0 0 0;position:relative;\"><iframe src=\"https://player.vimeo.com/video/640300645?h=37a894417d&amp;badge=0&amp;autopause=0&amp;player_id=0&amp;app_id=58479\" frameborder=\"0\" allow=\"autoplay; fullscreen; picture-in-picture\" allowfullscreen style=\"position:absolute;top:0;left:0;width:100%;height:100%;\" title=\"Footy Amigo Final HD.mp4\"></iframe></div><script src=\"https://player.vimeo.com/api/player.js\"></script>";"This system involves placing your Over 7.5 or 8.5 Corner bets at the 20th minute in a live match where there has been 0 corners at the 20th minute of the match. The reasoning is that - At the 20th minute of a match with 0 corners, the odds for Over 7.5, 8";"You will be learning an exciting corner betting strategy for betting the Over 7.5 or 8.5 corner markets profitably. Watch the video to know more. ";"1";"2021-10-29 10:27:19";"2021-10-30 10:15:59"
"8";"Over 0.5 Goals During 1st Half System 🐐";"This is one of our favorite betting systems because it combines a lot of interesting rules and conditions that must be met for a game to qualify to be bet on with this system. We will be using both live InPlay stats and PreMatch stats to filter matches that fits this system and are worthy of an Over 0.5 1st Half Goal bet. The is an ever improving system and it will keep getting better as time goes on.  ";"120";"<div style=\"padding:56.25% 0 0 0;position:relative;\"><iframe src=\"https://player.vimeo.com/video/640300645?h=37a894417d&amp;badge=0&amp;autopause=0&amp;player_id=0&amp;app_id=58479\" frameborder=\"0\" allow=\"autoplay; fullscreen; picture-in-picture\" allowfullscreen style=\"position:absolute;top:0;left:0;width:100%;height:100%;\" title=\"Footy Amigo Final HD.mp4\"></iframe></div><script src=\"https://player.vimeo.com/api/player.js\"></script>";"This system involves placing an Over 0.5 1st Goal bet at the 20th minute of a live match (you can also choose the 15th minute if you prefer). Regardless of the time you decide to use, some key conditions and rules must be met by the live game before considering betting on it. Watch video for full explanation.  ";"You will be learning an interesting Over 0.5 Goal Bet System that you can use to make quick profits on live matches. Watch the video to know more. ";"1";"2021-10-29 11:27:22";"2021-10-30 10:16:34"
"9";"The Lazy PreMatch Acca System ✌️";"PreMatch betting system anyone? Unlike the other systems we've shared, this is a PreMatch betting system that you can use day-in-day-out and with different markets. Its a \"set and leave\" system. Most of the systems we have shared required betting InPlay, this one on the other hand, requires being alerted at a specific time before kickoff and accumulating between 2-5 games that meets your set rules and conditions. ";"100";"<div style=\"padding:56.25% 0 0 0;position:relative;\"><iframe src=\"https://player.vimeo.com/video/640300645?h=37a894417d&amp;badge=0&amp;autopause=0&amp;player_id=0&amp;app_id=58479\" frameborder=\"0\" allow=\"autoplay; fullscreen; picture-in-picture\" allowfullscreen style=\"position:absolute;top:0;left:0;width:100%;height:100%;\" title=\"Footy Amigo Final HD.mp4\"></iframe></div><script src=\"https://player.vimeo.com/api/player.js\"></script>";"This system involves placing your bets Pre-Match before a game starts. The video above shows examples of different market where this Acca bet can be profitable. Watch video for full explanation. ";"You will be learning how to set and create a unique PreMatch Acca system for yourself. Create, Recieve Alert, Place Bet, Profit. Watch the video to know more. ";"1";"2021-10-29 11:39:28";"2021-10-30 10:16:47"

"""

# %%
with open("betting.json") as f:
  systems = f.read()

# %%
from datetime import datetime

# %%
datetime.utcnow().timestamp()
# Out:
# 1637073197.204562

# %%
import time

# %%
int(time.mktime(datetime.now().timetuple())), round(datetime.utcnow().timestamp())
# Out:
# (1637094777, 1637074977)

# %%
json.string
# Out:
# 1637094671

# %%
import json
systems = json.loads(systems)

# %%
for line in systems['data']:
  print(*line.values(), sep="\t")
# Out:
# 2	The £100 to £500,000 Compound System 🤑	Albert Einstein once said “Compound interest is the eighth wonder of the world. He who understands it, earns it … he who doesn't … pays it” . This betting system follows the compound interest concept. 	300	<div style="padding:56.25% 0 0 0;position:relative;"><iframe src="https://player.vimeo.com/video/640300645?h=37a894417d&amp;badge=0&amp;autopause=0&amp;player_id=0&amp;app_id=58479" frameborder="0" allow="autoplay; fullscreen; picture-in-picture" allowfullscreen style="position:absolute;top:0;left:0;width:100%;height:100%;" title="Footy Amigo Final HD.mp4"></iframe></div><script src="https://player.vimeo.com/api/player.js"></script>	This system follows setting aside a betting bank (£100 for example and building it to over £500,000 in 90days) by betting smart on small odds and compounding your profits daily. The video above explains the system and you also have corresponding preset st	You will be learning a compound interest betting system th
# ...

# %%
set([1,2,3]) | set([2,9,2])
# Out:
# {1, 2, 3, 9}

# %%
from datetime import datetime, date, timedelta

# %%
datetime.today()
# Out:
# datetime.datetime(2021, 11, 17, 4, 28, 21, 278714)

# %%
date.today().strftime("%Y-%m-%d")
# Out:
# '2021-11-17'

# %%
one_day = timedelta(days=1)

# %%
date.today()+ one_day
# Out:
# datetime.date(2021, 11, 18)

# %%
datetime(date.today())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1y/8g48f5zx3nn6c3b8x8xs5bc00000gn/T/ipykernel_13225/3546393432.py in <module>
# ----> 1 datetime(date.today())
#
# TypeError: an integer is required (got type datetime.date)

# %%
date.today().datetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/1y/8g48f5zx3nn6c3b8x8xs5bc00000gn/T/ipykernel_13225/83578616.py in <module>
# ----> 1 date.today().datetime()
#
# AttributeError: 'datetime.date' object has no attribute 'datetime'

# %%
today = date.today()
today_with_time = datetime(
    year=today.year, 
    month=today.month,
    day=today.day,
)

# %%
today_with_time
# Out:
# datetime.datetime(2021, 11, 17, 0, 0)

# %%
class Laora:
  def __init__(self):
    self.home = 1
    instance = self.__dict__
    print(instance)

# %%
l = Laora()
# Out:
# {'home': 1}

# %%
# Out:
# 1

# %%
items = """last_5.	total_goals_away_avg
last_5.	scored_away_avg
last_5.	conceded_away_avg
last_10.	total_goals_away_avg
last_10.	scored_away_avg
last_10.	conceded_away_avg
last_5.	won_away_per
last_5.	drawn_away_per
last_5.	lost_away_per
last_5.	btts_away_per
last_5.	clean_sheets_away_per
last_5.	fts_away_per
last_10.	won_away_per
last_10.	drawn_away_per
last_10.	lost_away_per
last_10.	btts_away_per
last_10.	clean_sheets_away_per
last_10.	fts_away_per
last_5.	o05_goals_away_per
last_5.	o15_goals_away_per
last_5.	o25_goals_away_per
last_5.	o35_goals_away_per
last_5.	o45_goals_away_per
last_10.	o05_goals_away_per
last_10.	o15_goals_away_per
last_10.	o25_goals_away_per
last_10.	o35_goals_away_per
last_10.	o45_goals_away_per
last_5.	o05_goals_1h_away_per
last_5.	o15_goals_1h_away_per
last_10.	o05_goals_1h_away_per
last_10.	o15_goals_1h_away_per
last_5.	o05_goals_2h_away_per
last_5.	o15_goals_2h_away_per
last_10.	o05_goals_2h_away_per
last_10.	o15_goals_2h_away_per
last_5.	o75_corners_away_per
last_5.	o85_corners_away_per
last_5.	o95_corners_away_per
last_5.	o105_corners_away_per
last_10.	o75_corners_away_per
last_10.	o85_corners_away_per
last_10.	o95_corners_away_per
last_10.	o105_corners_away_per
last_5.	o35_cards_away_per
last_5.	o45_cards_away_per
last_5.	o55_cards_away_per
last_10.	o35_cards_away_per
last_10.	o45_cards_away_per
last_10.	o55_cards_away_per"""

# %%
for i in items.splitlines():
  print("".join(i.split("\t")))
# Out:
# last_5.total_goals_away_avg
# last_5.scored_away_avg
# last_5.conceded_away_avg
# last_10.total_goals_away_avg
# last_10.scored_away_avg
# last_10.conceded_away_avg
# last_5.won_away_per
# last_5.drawn_away_per
# last_5.lost_away_per
# last_5.btts_away_per
# last_5.clean_sheets_away_per
# last_5.fts_away_per
# last_10.won_away_per
# last_10.drawn_away_per
# last_10.lost_away_per
# last_10.btts_away_per
# last_10.clean_sheets_away_per
# last_10.fts_away_per
# last_5.o05_goals_away_per
# last_5.o15_goals_away_per
# last_5.o25_goals_away_per
# last_5.o35_goals_away_per
# last_5.o45_goals_away_per
# last_10.o05_goals_away_per
# last_10.o15_goals_away_per
# last_10.o25_goals_away_per
# last_10.o35_goals_away_per
# last_10.o45_goals_away_per
# last_5.o05_goals_1h_away_per
# last_5.o15_goals_1h_away_per
# last_10.o05_goals_1h_away_per
# last_10.o15_goals_1h_away_per
# last_5.o05_goals_2h_away_per
# last_5.o15_goals_2h_away_per
# last_10.o05_goals_2h_away_per
# last_10.o15_goals_2h_away_per
# ...

# %%
with open("strike_rules.json") as f:
  data = f.read()

# %%
data= json.loads(data)

# %%
import json

# %%
for i in data["data"]:
  i["label"]= i["label"].replace("Over ", "+").replace("Match ", "")

# %%
print(json.dumps(data))
# Out:
# {"data": [{"id": 430, "code": "last_5.total_goals_avg", "label": "Avg. Goals in last 5 matches", "type": "avg", "min": 0, "max": 15, "step": 0.1, "inplay_only": 0, "description": "The average match goals in the last 5 matches played by team", "direct": 0, "category": "streak", "active": 1, "has_team": 0, "overall": "last_5.total_goals_overall_avg", "home": "last_5.total_goals_home_avg", "away": "last_5.total_goals_away_avg", "priority": 1}, {"id": 431, "code": "last_5.scored_avg", "label": "Avg. Goals Scored in last 5 matches", "type": "avg", "min": 0, "max": 6, "step": 0.05, "inplay_only": 0, "description": "The average goals SCORED by team in the last 5 matches played", "direct": 0, "category": "streak", "active": 1, "has_team": 0, "overall": "last_5.scored_overall_avg", "home": "last_5.scored_home_avg", "away": "last_5.scored_away_avg", "priority": 2}, {"id": 432, "code": "last_5.conceded_avg", "label": "Avg. Goals Conceded in last 5 matches", "type": "avg", "min": 0, "max": 6, "s
# ...

# %%
} E = 1 repeat sesame (e <= 2) print (e) that = 1 repeat sesame (that <= 3) {print (that) that + 1} e + 1

# %%
teams = """sum_of_teams
home
away
either_team
favorite
favorite_playing_home
favorite_playing_away
underdog
underdog_playing_home
underdog_playing_away
winning_team
losing_team"""

# %%
teams = teams.splitlines()

# %%
odds = ["dnb", "ft_result", "ht_result"]

# %%
types  = ["live_odds", "pre_odds"]

# %%
from itertools import product

# %%
def clean(text):
  text = text.replace(".", " ")
  text = text.replace("_", " ")
  text = " ".join(i.capitalize() for i in text.split())
  return text
for x,y,z in product(types, teams,odds):
  data = f"{x}.{y}.{z}"
  print(f'"{data}"', ":",f'"{clean(data)}", ')
# Out:
# "live_odds.sum_of_teams.dnb" : "Live Odds Sum Of Teams Dnb",
# "live_odds.sum_of_teams.ft_result" : "Live Odds Sum Of Teams Ft Result",
# "live_odds.sum_of_teams.ht_result" : "Live Odds Sum Of Teams Ht Result",
# "live_odds.home.dnb" : "Live Odds Home Dnb",
# "live_odds.home.ft_result" : "Live Odds Home Ft Result",
# "live_odds.home.ht_result" : "Live Odds Home Ht Result",
# "live_odds.away.dnb" : "Live Odds Away Dnb",
# "live_odds.away.ft_result" : "Live Odds Away Ft Result",
# "live_odds.away.ht_result" : "Live Odds Away Ht Result",
# "live_odds.either_team.dnb" : "Live Odds Either Team Dnb",
# "live_odds.either_team.ft_result" : "Live Odds Either Team Ft Result",
# "live_odds.either_team.ht_result" : "Live Odds Either Team Ht Result",
# "live_odds.favorite.dnb" : "Live Odds Favorite Dnb",
# "live_odds.favorite.ft_result" : "Live Odds Favorite Ft Result",
# "live_odds.favorite.ht_result" : "Live Odds Favorite Ht Result",
# ...
